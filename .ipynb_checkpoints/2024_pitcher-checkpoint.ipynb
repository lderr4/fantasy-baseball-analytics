# %%
import requests
import pandas as pd
from scipy.stats import norm
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option("display.max_rows", None)  
pd.set_option("display.max_columns", None) 
pd.set_option("display.width", 1000)

# %%
rp_url = "FantasyPros_2025_Projections_RP.csv"
sp_url = "FantasyPros_2025_Projections_SP.csv"
cats = ["Player", "Team", "Positions","ERA", "WHIP", "K", "QS", "SV+HD" ]
df1 = pd.read_csv(sp_url)
df2 = pd.read_csv(rp_url)
df1["SV+HD"] = 0
df1 = df1[cats]
df1["primary_position"] = "SP"

df1 = df1.head(100)

df2["SV+HD"] = df2["SV"] + df2["HD"]
df2["QS"] = 0
df2 = df2[cats]
df2["primary_position"] = "RP"

df2 = df2.head(50)

# %%
def calculate_data_cats(df, cats):
    
    data_cats = []
    for cat in cats:
        if cat=="WHIP" or cat=="ERA":
            x = -1*df[cat]
            
        else:
            x = df[cat]
        mean = np.mean(x)
        std = np.std(x)
        z_score = (x - mean) / std
        percentile = norm.cdf(z_score)

        data_cat = f"{cat}_percentile"
        df[data_cat] = pd.Series(percentile)


sp_cats = ["QS"]
calculate_data_cats(df1, sp_cats)
df1["SV+HD_percentile"] = 0

rp_cats = ["SV+HD"]
calculate_data_cats(df2, rp_cats)

df2["QS_percentile"] = 0

df = pd.concat([df1, df2])
df = df.drop_duplicates(subset=["Player", "Team"], keep="first")

cats = ["ERA", "WHIP", "K"]
calculate_data_cats(df, cats)

del df1
del df2

# %%
adp_url = "FantasyPros_2025_Overall_MLB_ADP_Rankings.csv"

df_adp = pd.read_csv(adp_url)
df_adp.rename(columns={"AVG": "adp_avg"}, inplace=True)

df_adp["adp_sd"] = df_adp.apply(lambda x: np.std(x[["Yahoo", "RTS", "NFBC", "FT"]]), axis=1)

df_adp = df_adp.drop(["Rank","Team", "Positions", "Yahoo", "RTS", "NFBC", "FT"],axis=1)

# %%
df = df.merge(df_adp, on="Player", how="inner")

# %%
def get_ap(row):
    if row["primary_position"] == "SP":
        return np.mean(row[['ERA_percentile', 'WHIP_percentile', 'K_percentile', 'QS_percentile', ]])
    elif row["primary_position"]:

        return np.mean(row[['ERA_percentile', 'WHIP_percentile', 'K_percentile', 'SV+HD_percentile']])
        

col = 'average_percentile'
data_cats=['ERA_percentile', 'WHIP_percentile', 'K_percentile', 'QS_percentile', 'SV+HD_percentile']
df[col] = df.apply(get_ap, axis=1)
data_cats.append(col)

# %%
df
# Out:
#                     Player Team Positions   ERA  WHIP      K    QS  SV+HD primary_position  QS_percentile  SV+HD_percentile  ERA_percentile  WHIP_percentile  K_percentile adp_avg      adp_sd  average_percentile
# 0             Tarik Skubal  DET        SP  2.88  1.01  221.0  20.0    0.0               SP       0.976569          0.000000        0.972847         0.987539      0.976329    14.3    1.785357            0.978321
# 1              Paul Skenes  PIT        SP  2.83  1.05  211.0  19.0    0.0               SP       0.951499          0.000000        0.979543         0.960456      0.960916    12.8    1.479020            0.963103
# 2             Zack Wheeler  PHI        SP  3.30  1.08  210.0  19.0    0.0               SP       0.951499          0.000000        0.820234         0.917894      0.959003    21.0    1.870829            0.912157
# ...

# %%
df['adp_avg'] = pd.to_numeric(df['adp_avg'], errors='coerce')

df['adp_avg'] = df['adp_avg'].fillna(0)  # Or use dropna() if you prefer to remove rows with NaN

df['round'] = (df['adp_avg'] // 12 + 1).astype(int)

df['round'] = df['round'].clip(upper=24)

# %%
round_by_round = df.groupby(['round', "primary_position"])['average_percentile'].mean().reset_index()

round_by_round
# Out:
#     round primary_position  average_percentile
# 0       1               SP            0.547545
# 1       2               SP            0.951194
# 2       3               SP            0.848175
# 3       4               RP            0.962497
# 4       4               SP            0.805016
# 5       5               SP            0.738631
# 6       6               RP            0.918742
# 7       6               SP            0.741783
# 8       7               RP            0.895318
# 9       7               SP            0.684721
# 10      8               RP            0.765493
# 11      8               SP            0.711101
# 12      9               RP            0.783578
# 13      9               SP            0.649723
# 14     10               RP            0.710153
# 15     10               SP            0.646214
# 16     11               RP            0.782427
# 17     11               SP            0.680170
# 18     12               RP            0.712833
# ...

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=round_by_round, x='round', y='average_percentile', hue='primary_position')

plt.title('Average Percentile by Draft Round and Position Eligibility')
plt.xlabel('Draft Round')
plt.ylabel('Average Percentile')
plt.legend(title='Position Eligibility', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %%
def get_rel_percent(row):
    position = row["primary_position"]
    
    r = round_by_round[(round_by_round["round"] == row["round"]) &
                       (round_by_round["primary_position"] == position)]["average_percentile"]
    
 
    ans = 0
    
    try:
        ans = (row["average_percentile"] - r).iloc[0]
        return ans
    except:
        print(row)
        return None
        
        
    
    
df['relative_percentile'] = df.apply(get_rel_percent,axis=1)

# %%
pd.set_option("display.max_rows", None)  # Show all rows
pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.width", 1000)  # Prevent line breaks
df = df.sort_values(by='relative_percentile', ascending=False)
# Drop rows with NaN in 'relative_percentile' before ranking
df = df.dropna(subset=['relative_percentile'])

# Now, apply the rank
df["rp_rank"] = df["relative_percentile"].rank(method="dense", ascending=False).astype(int)
df["p_rank"] = df["average_percentile"].rank(method="dense", ascending=False).astype(int)

# %%
from IPython.display import display

display_cats = ["rp_rank", "p_rank", "Player", "Positions","ERA_percentile",
                "WHIP_percentile",
                "K_percentile",
                "QS_percentile",
                "SV+HD_percentile", "relative_percentile","adp_avg"]


display(df[df["adp_avg"] < 120][display_cats])
# Out:
#      rp_rank  p_rank                 Player Positions  ERA_percentile  WHIP_percentile  K_percentile  QS_percentile  SV+HD_percentile  relative_percentile  adp_avg
# 32         8      24             Sonny Gray        SP        0.642140         0.705218      0.877483       0.842216          0.000000             0.120551    111.0
# 5          9       5             Chris Sale        SP        0.911221         0.917894      0.952805       0.908502          0.000000             0.117590     36.5
# 20        23      19          Tyler Glasnow        SP        0.832543         0.948907      0.808976       0.507850          0.000000             0.063468     91.3
# 29        24      40               Joe Ryan        SP        0.444377         0.917894      0.837698       0.635950          0.000000             0.062766    110.3
# 15        26      15           Jacob deGrom        SP        0.958396         0.999013      0.720982       0.507850          0.000000             0.057929     55.5
# ...

# %%
from IPython.display import display

display_cats = ["rp_rank", "p_rank","adp_avg","Player", "Positions", "ERA_percentile",
                "WHIP_percentile",
                "K_percentile",
                "QS_percentile",
                "SV+HD_percentile", "relative_percentile",]

display(df.sort_values(by='average_percentile', ascending=False)[display_cats])
# Out:
#      rp_rank  p_rank  adp_avg                 Player Positions  ERA_percentile  WHIP_percentile  K_percentile  QS_percentile  SV+HD_percentile  relative_percentile
# 0         56       1     14.3           Tarik Skubal        SP        0.972847         0.987539      0.976329       0.976569          0.000000             0.027127
# 1         67       2     12.8            Paul Skenes        SP        0.979543         0.960456      0.960916       0.951499          0.000000             0.011909
# 100       76       3     46.8         Emmanuel Clase        RP        0.972847         0.987539      0.976329       0.000000          0.913273             0.000000
# 101       60       4     61.8         Devin Williams        RP        0.979543         0.960456      0.960916       0.000000          0.875944             0.025473
# 5          9       5     36.5             Chris Sale        SP        0.911221         0.917894      0.952805       0.908502          0.000000             0.117590
# ...
